# %%
import time
from typing import List

import pandas as pd
from dataclasses import dataclass

import pyautogui
import textract
from platform import platform

if "Windows" in platform():
    from pywinauto.keyboard import send_keys


@dataclass
class Entry:
    index: str = ""
    code: str = ""
    description: str = ""
    location: str = ""
    quantity: str = ""
    cost: str = ""
    price: str = ""
    notes: str = ""

    def __getitem__(self, key):
        return getattr(self, key)
    
    def __setitem__(self, key, value):
        setattr(self, key, value)

attrs = {
    "index": '#',
    "code": "Stock#",
    "description": "Description",
    "cost": "Cost",
}

# So here's how the bot is going to need to work
# Step 1: Read the Excel sheet
# Do this by opening every page in the spreadsheet using pandas
# and then read row by row to assemble a list of entries

entries: List[Entry] = []
dfs = pd.read_excel("cougarbot_data/stock.xls", sheet_name=None)
for sheet_name, df in dfs.items():
    df = df.astype(str)
    titles = list(df.iloc[0])
    indices = {
        attr: titles.index(value) + 1 for attr, value in attrs.items()
    }

    indices["price"] = titles.index("Cost") + 3
    qindex = titles.index("Abdn") + 1
    for row in df.itertuples():
        if row[indices["index"]] not in ["nan", '#']:
            if row[qindex + 1] == "nan" or row[qindex] == 'X':
                entry = Entry()
                for attr, index in indices.items():
                    entry[attr] = row[index]

                q = row[qindex] if row[qindex].isnumeric() else '1'
                entry["quantity"] = q
                entry["location"] = "ABDN"
                entries.append(entry)

            if row[qindex + 1] != "nan":
                entry = Entry()
                for attr, index in indices.items():
                    entry[attr] = row[index]

                q = '1' if row[qindex + 1] == 'X' else row[qindex + 1]
                entry["quantity"] = q
                entry["location"] = "HBY"
                entries.append(entry)

print(entries)
# Out:
# [Entry(index='1', code='J10-0318', description='pin,sp,mop,b-fly,cryst,center-row,1.4in', location='HBY', quantity='20', cost='14', price='59.0', notes=''), Entry(index='1b', code='F10-0320', description='pin,gp,mop,dark,b-fly,cryst,1row,1.4in', location='HBY', quantity='20', cost='14', price='59.0', notes=''), Entry(index='2', code='G06-0313', description='neck,ss,prl,1,cryst,2inlock-ov,haro,', location='ABDN', quantity='1', cost='15.9', price='49.0', notes=''), Entry(index='3', code='G08-0321', description='ear,ss,prl,1,cryst,2inlock-ov,haro,stud', location='ABDN', quantity='1', cost='17.9', price='49.0', notes=''), Entry(index='4', code='7G08-0098', description='ear,ss,cryst,blu,tri,1,wht-sur', location='ABDN', quantity='1', cost='13.5', price='39.5', notes=''), Entry(index='5', code='7G06-0296', description='neck,ss,cryst,blu,tri,1,wht-sur', location='ABDN', quantity='1', cost='9.6', price='39.5', notes=''), Entry(index='6', code='G01-0150', description='ring,ss,cryst,1lg-center,pave-side', location='ABDN', quantity='1', cost='9', price='29.5', notes=''), Entry(index='7', code='G01-0033', description='ring,ss,cryst,3,rnd,side,fancy,$35', location='ABDN', quantity='1', cost='10.15', price='nan', notes=''), Entry(index='8', code='7G08-0276', description='ear,ss,cryst,hum-bird,body-paved,.5in', location='ABDN', quantity='1', cost='7', price='22.5', notes=''), Entry(index='9', code='G06-0086', description='neck,ss,cryst,snow-flake,paved,sm', location='HBY', quantity='8', cost='6.65', price='29.5', notes=''), Entry(index='10,11', code='G06-0056', description='neck,ss,cryst,snow-flake,lg', location='HBY', quantity='10', cost='14', price='49.0', notes=''), Entry(index='12', code='G06-0060', description='neck,ss,prl,1,wht,cryst,3curve,haro,', location='ABDN', quantity='1', cost='11.9', price='49.0', notes=''), Entry(index='12b', code='G06-0090', description='neck,ss,prl,1,p-ck,cryst,3curve,haro,', location='ABDN', quantity='1', cost='11.9', price='49.0', notes=''), Entry(index='13', code='G06-0126', description='neck,ss,cryst,dr-fly,grn,blu&wht,20mm', location='HBY', quantity='1', cost='8.4', price='26.95', notes=''), Entry(index='13b', code='AP8982', description='neck,ss,cryst,dr-fly,pur,pnk&wht,20mm', location='ABDN', quantity='1', cost='8.4', price='28.0', notes=''), Entry(index='14', code='G08-0018', description='ear,ss,cryst,dr-fly,grn,blu&wht,chn', location='HBY', quantity='1', cost='10.5', price='29.5', notes=''), Entry(index='14b', code='G08-0024', description='ear,ss,cryst,dr-fly,pur,pnk&wht,chn', location='ABDN', quantity='1', cost='10.5', price='28.0', notes=''), Entry(index='15', code='G08-0118', description='ear,ss,g-ov,cryst,pave,rnd-under,lg', location='ABDN', quantity='1', cost='8.5', price='32.95', notes=''), Entry(index='16', code='G06-0013', description='neck,ss,g-ov,cryst,pave,sq,rnd-under,lg', location='HBY', quantity='1', cost='13', price='29.5', notes=''), Entry(index='17', code='G06-0037', description='neck,ss,jdr-bc,rnd,cab,cryst-sq-top,', location='HBY', quantity='12', cost='18.2', price='69.0', notes=''), Entry(index='18', code='G06-0209', description='neck,ss,jdr-bc,ball-drop,hum-bird,', location='ABDN', quantity='1', cost='17.5', price='49.0', notes=''), Entry(index='19', code='G08-0064', description='ear,ss,jdr-bc,ball-stud,8mm', location='ABDN', quantity='1', cost='7', price='28.0', notes=''), Entry(index='20', code='G06-0237', description='neck,ss,jde-bc,ball,1,slide', location='ABDN', quantity='1', cost='9.45', price='29.5', notes=''), Entry(index='21', code='G06-0287', description='neck,ss,jdr-bc,ball-drop,ss-O-top', location='ABDN', quantity='1', cost='13.3', price='39.5', notes=''), Entry(index='22', code='G08-0068', description='ear,ss,jdr-bc,ball-drop,ss-O-top', location='HBY', quantity='12', cost='16.1', price='39.5', notes=''), Entry(index='23', code='G06-0163', description='neck,ss,jdr-bc,ball-drop,ss-O-haro,slide', location='HBY', quantity='12', cost='10.5', price='39.5', notes=''), Entry( ...

# %%
len(entries)
# Out:
# 28

# %%
list(dfs.values())[1]
# Out:
#     Box Unnamed: 1                                         Unnamed: 2  \
# 0     #     Stock#                                        Description
# 1   NaN        NaN  Paid to A&H by ck#00746 $8873.82 ($11308.40-$3...
# 2   NaN        NaN                                                NaN
# 3    16   G06-0013            neck,ss,g-ov,cryst,pave,sq,rnd-under,lg
# 4   NaN        NaN                                            SPS001G
# 5    17   G06-0037               neck,ss,jdr-bc,rnd,cab,cryst-sq-top,
# 6   NaN        NaN                       JN708   Abdn has 36 G06-0037
# 7    18   G06-0209                 neck,ss,jdr-bc,ball-drop,hum-bird,
# 8   NaN        NaN                                             JN1905
# 9    19   G08-0064                        ear,ss,jdr-bc,ball-stud,8mm
# 10  NaN        NaN                                            JN19081
# 11   20   G06-0237                        neck,ss,jde-bc,ball,1,slide
# 12  NaN        NaN                                             JN1904
# 13   21   G06-0287                  neck,ss,jdr-bc,ball-drop,ss-O-top
# 14  NaN        NaN                                             H1602N
# 15   22   G08-0068                   ear,ss,jdr-bc,ball-drop,ss-O-top
# 16  NaN        NaN                     H1602E    Abdn has 10 G08-0068
# 17   23   G06-0163           neck,ss,jdr-bc,ball-drop,ss-O-haro,slide
# 18  NaN        NaN                JN1906        Abdn has one G06-0163
# 19   24   G06-0167                         neck,ss,cryst-by-yard,18in
# 20  NaN        NaN                                             LN0054
# 21   25   G06-0197                         neck,ss,cryst-by-yard,22in
# 22  NaN        NaN                                             LN0055
# 23  NaN        NaN                                                NaN
# 24  NaN        NaN                                                NaN
# 25  NaN        NaN                                                NaN
# 26  NaN        NaN                                                NaN
# 27  NaN        NaN                                               AP00
#
#    Unnamed: 3   Unnamed: 4   Total  Sell Price Unnamed: 7 OUT TO Unnamed: 9  \
# 0        Qty.         Cost    Cost         NaN         BC    POL        REP
# 1         NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 2         NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 3           2           13      26        29.5        NaN    NaN        NaN
# 4         NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 5          52         18.2   946.4        69.0        NaN    NaN        NaN
# 6         NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 7          10         17.5     175        49.0        NaN    NaN        NaN
# 8         NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 9           9            7      63        28.0        NaN    NaN        NaN
# 10        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 11          6         9.45    56.7        29.5        NaN    NaN        NaN
# 12        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 13         16         13.3   212.8        39.5        NaN    NaN        NaN
# 14        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 15         22         16.1   354.2        39.5        NaN    NaN        NaN
# 16        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 17         12         10.5     126        39.5        NaN    NaN        NaN
# 18        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 19          4         10.5      42        36.0        NaN    NaN        NaN
# 20        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 21          3         13.3    39.9        39.5        NaN    NaN        NaN
# 22        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 23        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 24        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 25        NaN  Total Cost:  2042.0         NaN        NaN    NaN        NaN
# 26        NaN          NaN     NaN         NaN        NaN    NaN        NaN
# 27        NaN          NaN     NaN         NaN        NaN    NaN        NaN
#
#    Unnamed: 10 STORE Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0          APP  Abdn         Hby        Ware        Sign          Lg
# 1          NaN   NaN         NaN         NaN         NaN         NaN
# 2          NaN   NaN         NaN         NaN         NaN         NaN
# 3          NaN   NaN           X         NaN         NaN         NaN
# 4          NaN   NaN         NaN         NaN         NaN         NaN
# 5          NaN    40          12         NaN         NaN         NaN
# 6          NaN   NaN         NaN         NaN         NaN         NaN
# 7          NaN   NaN         NaN         NaN         NaN         NaN
# 8          NaN   NaN         NaN         NaN         NaN         NaN
# 9          NaN   NaN         NaN         NaN         NaN         NaN
# 10         NaN   NaN         NaN         NaN         NaN         NaN
# 11         NaN   NaN         NaN         NaN         NaN         NaN
# 12         NaN   NaN         NaN         NaN         NaN         NaN
# 13         NaN   NaN         NaN         NaN         NaN         NaN
# 14         NaN   NaN         NaN         NaN         NaN         NaN
# 15         NaN   NaN          12         NaN         NaN         NaN
# 16         NaN   NaN         NaN         NaN         NaN         NaN
# 17         NaN   NaN          12         NaN         NaN         NaN
# 18         NaN   NaN         NaN         NaN         NaN         NaN
# 19         NaN   NaN         NaN         NaN         NaN         NaN
# 20         NaN   NaN         NaN         NaN         NaN         NaN
# 21         NaN   NaN         NaN         NaN         NaN         NaN
# 22         NaN   NaN         NaN         NaN         NaN         NaN
# 23         NaN   NaN         NaN         NaN         NaN         NaN
# 24         NaN   NaN         NaN         NaN         NaN         NaN
# 25         NaN   NaN         NaN         NaN         NaN         NaN
# 26         NaN   NaN         NaN         NaN         NaN         NaN
# 27         NaN   NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 16
# 0        Notes
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
